# %% [markdown]
# # Text Analysis in Python 2: Word Counts / Words Count
#
# <h1 style="text-align:center;font-size:300%;">The United States is / are ____?</h1>
#   <img src="https://miro.medium.com/max/720/1*pp7HX01jBv2wbVRW9Ml_mA.png" style="width:%80;">
#   <!--<img src="http://www.languagetrainers.com/blog/wp-content/uploads/2012/10/us-are-vs-us-is1.png" style="width:%140;">-->
#
# From Benjamin Schmidt and Mitch Fraas, ["The Language of the State of the Union](https://www.theatlantic.com/politics/archive/2015/01/the-language-of-the-state-of-the-union/384575/)," *The Atlantic* (Jan. 15, 2015).  **Can we create our own version of this graph?**
#
# ## This Lesson
#
# **Exploring the frequency of words and phrases in texts: what can they tell us about a text?**
#
# In this session, participants will:
# + Apply Python (and the NLTK package) to read individual text files and apply essential pre-processing techniques (i.e. divide each text into a list of words or tokens, lower-case all words, remove punctuation, and lemmatize each word).
# + Create frequency lists identifying the most common words or ngrams (multi-word terms) in a text or corpus
# + Create graphs, charts, and word clouds visually representing word and term frequency patterns
# + Identify some ways the language of State of the Union speeches has changed over time and discuss how this method could be applied to other texts and questions
#
# **In short, one of our goals today is to recreate the graphic above (from *The Atlantic*) showing changes in the frequency of particular words or terms - as used in the State of the Union address - over time.**
#
#
# ## Structure of Notebooks
#
# These Jupyter Notebooks are designed to integrate instructions and explanations (in the white "markdown" cells below) with hands-on practice with the code (in the gray "code" cells below). To add, modify, or delete cells, please use the Menu above (especially under the Edit, Insert, and Cell tabs) or click ESC + H to see a list of keyboard shortcuts.
#
# <h3 style="color:green">Code Together:</h3><p style="color:green">In these cell blocks, we will code together. You can find the completed version in our shared folder (ending with "_completed.ipynb").</p>
#
# <h3 style="color:blue;">Exercises:</h3><p style="color:blue">are in blue text. These are a chance to practice what you have learned.</p>
#
# <h3 style="color:purple">Python Basics - Additional Practice</h3><p style="color:purple">are in purple text. Work on these after the lesson if you would like more practice.</p>
#
# ## Lists of Words, Frequency Lists, N-Grams, and Dispersion Plots
#
# *[intro / explanation / beg instructions / links back to prev notebooks]*

# %% [markdown]
# ## Part I: Getting Started - Importing Python Packages, SOTU texts, and tokenizing

# %% [markdown]
# 1. First, we will need to import the necessary Python packages or libraries for today's lesson.

# %%
import os, nltk, re, collections, pathlib, time
import pandas as pd
import matplotlib as plt
import seaborn as sns
from pathlib import Path
from nltk.tokenize import RegexpTokenizer
from nltk import ngrams, pos_tag, word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from collections import Counter

plt.rcParams['figure.figsize'] = [12, 6]  #changes default figure size to make larger plots

# %config InteractiveShellApp.matplotlib = 'inline'
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# 2. Navigate to and examine the folder that has your SOTU files. As in the previous lesson, we use the **pathlib** library and its functions to work with paths to files and folders (directories). For more on the challenges of working with filepaths across operating systems and how pathlib addresses see ["Python 3's pathlib module: Taming the File System."](https://realpython.com/python-pathlib/)

# %%
p = Path.cwd()
p2 = p.parent
sotudir = Path(p2,"state-of-the-union-dataset","txt")
print(sotudir)
pathlist = sotudir.glob("*.txt")
for path in pathlist:
    print(path)
# Out:
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\
txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1974_Nixon.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1975_Ford.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1976_Ford.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1977_Ford.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1978_Carter.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1979_Carter.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1980_Carter.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1981_Carter.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1982_Reagan.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1983_Reagan.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1984_Reagan.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1985_Reagan.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1986_Reagan.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1987_Reagan.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1988_Reagan.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1989_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1990_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1991_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1992_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1993_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1994_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1995_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1996_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1997_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1998_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\1999_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2000_Clinton.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2001_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2002_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2003_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2004_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2005_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2006_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2007_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2008_Bush.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2009_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2010_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2011_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2012_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2013_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2014_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2015_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2016_Obama.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2017_Trump.txt
# C:\Users\F0040RP\Documents\DartLib_RDS\textAnalysis\state-of-the-union-dataset\txt\2018_Trump.txt

# %% [markdown]
# 3. Open the George Washington's 1794 SOTU address:
#
# *Note*: In Python, it is recommended that you always close your files after finishing with them. One way to do this is to place an **open()** command within a **with statement**. This way, the files is closed as soon as we exit the indented block underneath the with statement. See [Why Close Python Files](https://realpython.com/why-close-file-python/).

# %%
sotuid = "1794_Washington"
with open(Path(sotudir,'%s.txt'%sotuid)) as f:
    wash94=f.read()

# %% [markdown]
# <p style='color:green'>3b. <b>Code Together:</b> Print the first 400 characters of this address.</p>

# %%
#insert code here

# %% [markdown]
# 4. Tokenize this address and count the number of tokens.

# %% [markdown]
# We can then tokenize this SOTU address and count the number of tokens in it.

# %%
#if we wanted all punctuation, including tokens we could just run the following code:
tokens = word_tokenize(wash94)  #this command uses the function word_tokenize() from the package ntlk (which we imported at the beginning of the lesson)
# however, we can remove punction tokens using the regTokenizer from ntlk:
#from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokens2=tokenizer.tokenize(wash94)
print(len(tokens2))
# Out:
# 2918

# %% [markdown]
# <h3 style = "color:green">Code Together: Words Count</h3>

# %% [markdown]
# <p style = "color:green">5. We counted the number of tokens within Washington's 1794 address. Choose another SOTU address and compute and print out the number of words contained within it.</p>

# %% [markdown]
# <h3 style = "color:purple">Part II. Python Basics: For Loops vs. List Comprehensions</h3>
#
# <p style = "color:purple">6. <b>LIST COMPREHENSIONS</b>: In the previous lesson we converted all tokens to lowercase using a simple <b>for loop</b>. For more on list comprehensions see: <a href="https://www.w3schools.com/python/python_lists_comprehension.asp">w3schools</a> or <a href="https://realpython.com/list-comprehension-python/">realpython</a>.</p>

# %%
ltokens2 = []                      #assigns an empty list to the variable ltokens2
for tok in tokens2:                #iterates through our tokens2 list we created above, assigning the variable name "tok" to each item in the list as it goes
    ltokens2.append(tok.lower())   #lowercases each item ("tok") from tokens2 list and adds it to ltokens2 list (tokens2 is not permanently changed)

# %%
print("tokens2 list: \n",tokens2[:40],"\n\n")
print("ltokens2 list: \n",ltokens2[:40])
# Out:
# tokens2 list:
#  ['Fellow', 'Citizens', 'of', 'the', 'Senate', 'and', 'House', 'of', 'Representatives', 'When', 'we', 'call', 'to', 'mind', 'the', 'gracious', 'indulgence', 'of', 'Heaven', 'by', 'which', 'the', 'American', 'people', 'became', 'a', 'nation', 'when', 'we', 'survey', 'the', 'general', 'prosperity', 'of', 'our', 'country', 'and', 'look', 'forward', 'to']
#
#
# ltokens2 list:
#  ['fellow', 'citizens', 'of', 'the', 'senate', 'and', 'house', 'of', 'representatives', 'when', 'we', 'call', 'to', 'mind', 'the', 'gracious', 'indulgence', 'of', 'heaven', 'by', 'which', 'the', 'american', 'people', 'became', 'a', 'nation', 'when', 'we', 'survey', 'the', 'general', 'prosperity', 'of', 'our', 'country', 'and', 'look', 'forward', 'to']

# %% [markdown]
# <p style = "color:purple">We can do the same thing using a <b>list comprehension</b>. The formula for list comprehensions is:</p>
#
#     newList = [item (or modified item) for item in oldList]
#
# <p style = "color:purple">You can also add a conditional:</p>
#
#     newList = [item or (modified item) for item in oldList if item meets condition]
#
#  <p style = "color:purple">7. To create a new list of tokens that have been converted to lower case, we can create the following list comprehension</p>

# %%
ltokens2=[tok.lower() for tok in tokens2]
print("ltokens2 list created using a list comprehension: \n",ltokens2[:40])
# Out:
# ltokens2 list created using a list comprehension:
#  ['fellow', 'citizens', 'of', 'the', 'senate', 'and', 'house', 'of', 'representatives', 'when', 'we', 'call', 'to', 'mind', 'the', 'gracious', 'indulgence', 'of', 'heaven', 'by', 'which', 'the', 'american', 'people', 'became', 'a', 'nation', 'when', 'we', 'survey', 'the', 'general', 'prosperity', 'of', 'our', 'country', 'and', 'look', 'forward', 'to']

# %%
#here is an example of a list comprehension with a conditional. 

ltokens3 = [tok.upper() for tok in tokens2 if tok.startswith("T")]
print(ltokens3,"\nWhat does this code do?")
# Out:
# ['THE', 'THE', 'THEY', 'THEY', 'THEY', 'THUS', 'THIRTY', 'THE', 'THE', 'TO', 'THE', 'THE', 'TOWARD', 'THE', 'THE', 'THE', 'THERE']
# What does this code do?

# %% [markdown]
# ## Part III. Creating Frequency Lists
#
# 8. As with most tasks in Python or other popular programming languages, there are multiple ways to count unique items in a list and create frequency items of them. First, we will use the **collections** package.

# %%
numsList = [3,2,2]                         #INSERT ADDITIONAL NUMBERS IN THIS LIST, include repeats       
numfreqs = collections.Counter(numsList)   #using the function "Counter" from the package "collections" - creates a 
                                                  ## frequency list from numslist
print(numfreqs)  #print out the frequency list
# Out:
# Counter({2: 2, 3: 1})

# %% [markdown]
# 9. Let's apply the same method to create a frequency list of our tokens from out list of lowercase tokens (ltokens2)

# %%
tokfreqs=collections.Counter(ltokens2)

# %% [markdown]
# 9b. To view the most or least common tokens in our list, run:

# %%
print(tokfreqs.most_common(60))
print("\n")
print(tokfreqs.most_common()[:-60:-1]) #there is no function for returning the least common tokens
     #however, we can essentially do the same thing with the above code 
    # by taking the tokens found at the end of the ordered list of most common tokens (the extra ":" before -60
    # returns the end of this list in reverse)
# Out:
# [('the', 273), ('of', 187), ('to', 138), ('and', 86), ('a', 48), ('that', 39), ('by', 36), ('be', 36), ('in', 36), ('which', 34), ('not', 32), ('have', 30), ('been', 24), ('our', 22), ('it', 22), ('were', 20), ('states', 19), ('as', 19), ('from', 19), ('i', 18), ('an', 18), ('with', 17), ('was', 17), ('their', 17), ('united', 15), ('this', 15), ('government', 14), ('for', 14), ('will', 14), ('them', 13), ('has', 13), ('is', 12), ('they', 12), ('or', 12), ('on', 12), ('laws', 12), ('may', 12), ('who', 11), ('my', 11), ('would', 10), ('too', 10), ('militia', 10), ('all', 10), ('citizens', 9), ('can', 9), ('at', 9), ('but', 9), ('its', 8), ('constitution', 8), ('pennsylvania', 8), ('into', 8), ('against', 8), ('had', 8), ('upon', 8), ('other', 8), ('such', 8), ('are', 8), ('men', 7), ('congress', 7), ('every', 7)]
#
#
# [('go', 1), ('safeguard', 1), ('anticipations', 1), ('verify', 1), ('conferred', 1), ('goodness', 1), ('perpetuate', 1), ('flight', 1), ('invasion', 1), ('sedition', 1), ('internal', 1), ('out', 1), ('root', 1), ('times', 1), ('enable', 1), ('confirming', 1), ('wicked', 1), ('machinations', 1), ('turn', 1), ('protection', 1), ('holy', 1), ('spread', 1), ('ruler', 1), ('imploring', 1), ('ourselves', 1), ('insist', 1), ('acquiring', 1), ('lose', 1), ('right', 1), ('acquired', 1), ('injurious', 1), ('correct', 1), ('misapprehended', 1), ('explain', 1), ('impartiality', 1), ('line', 1), ('deviation', 1), ('check', 1), ('faith', 1), ('absolute', 1), ('pure', 1), ('treaties', 1), ('observe', 1), ('world', 1), ('cultivate', 1), ('transactions', 1), ('unseasonable', 1), ('transmitted', 1), ('intercourse', 1), ('circumstances', 1), ('communications', 1), ('subsequent', 1), ('utility', 1), ('formed', 1), ('originally', 1), ('realize', 1), ('day', 1), ('remote', 1), ('institution', 1)]

# %% [markdown]
# 10. Remove stop words
#
# The token list above, especially the most common words, does not provide much information about the content of this address. We can learn more by first removing **stop words** from the text. Stop words are common words that reveal little about the meaning of a text (such as articles like "the", conjunctions like "and", prepositions like "on", pronouns like "our", and helper verbs like "can"). Fortunately, NLTK provides a list of stop words in English (and other languages as well) that we can use to eliminate all such words from our texts.
#
# To get an idea of how stop words work, first we will take our list of numbers (numsList) created above and create a copy of this list with all 3s and 7s removed. For texts, we can basically do the same thing: remove all stop words ("a", "this", "that", etc.) from a list of tokens.

# %%
print(numsList)
stopNums = [3,7]
newNumsList = [num for num in numsList if num not in stopNums]
print(newNumsList)
# Out:
# [3, 2, 2]
# [2, 2]

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))
print("\n***\n")
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
#
# ***

# %% [markdown]
# <p style="color:green">10b. <b>Code Together</b>: Print out stopwords from another language.</p>

# %%
# languages in nltk
print(stopwords.fileids())

# print out stopwords from a language of your choice
# Out:
# ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
stop=stopwords.words('english')
print("We had",len(ltokens2),"tokens in our token list.")
print("beginning with:",ltokens2[:30]," \n")

ltokens3=[tok for tok in ltokens2 if tok not in stop]        #list comprehension removes all stopwords from ltokens2
print("After removing stop words, we now have",len(ltokens3),"tokens in our list.")
print("beginning with:",ltokens3[:30])

# this for loop accomplishes the same thing as the list comprehension above
#ltokens3=[]
#for tok in ltokens2:
#    if not tok in stop:
#        ltokens3.append(tok)
# Out:
# We had 2918 tokens in our token list.
# beginning with: ['fellow', 'citizens', 'of', 'the', 'senate', 'and', 'house', 'of', 'representatives', 'when', 'we', 'call', 'to', 'mind', 'the', 'gracious', 'indulgence', 'of', 'heaven', 'by', 'which', 'the', 'american', 'people', 'became', 'a', 'nation', 'when', 'we', 'survey']
#
# After removing stop words, we now have 1347 tokens in our list.
# beginning with: ['fellow', 'citizens', 'senate', 'house', 'representatives', 'call', 'mind', 'gracious', 'indulgence', 'heaven', 'american', 'people', 'became', 'nation', 'survey', 'general', 'prosperity', 'country', 'look', 'forward', 'riches', 'power', 'happiness', 'seems', 'destined', 'deepest', 'regret', 'announce', 'recess', 'citizens']

# %% [markdown]
# 11. Thus, our new frequency list of words looks like this:

# %%
n=50
print("previously, our most common",n,"tokens were:",tokfreqs.most_common(n))
tokfreqsB=collections.Counter(ltokens3)
print("\nNow our most common",n,"tokens (after removing stop words) are:",tokfreqsB.most_common(n))
# Out:
# previously, our most common 50 tokens were: [('the', 273), ('of', 187), ('to', 138), ('and', 86), ('a', 48), ('that', 39), ('by', 36), ('be', 36), ('in', 36), ('which', 34), ('not', 32), ('have', 30), ('been', 24), ('our', 22), ('it', 22), ('were', 20), ('states', 19), ('as', 19), ('from', 19), ('i', 18), ('an', 18), ('with', 17), ('was', 17), ('their', 17), ('united', 15), ('this', 15), ('government', 14), ('for', 14), ('will', 14), ('them', 13), ('has', 13), ('is', 12), ('they', 12), ('or', 12), ('on', 12), ('laws', 12), ('may', 12), ('who', 11), ('my', 11), ('would', 10), ('too', 10), ('militia', 10), ('all', 10), ('citizens', 9), ('can', 9), ('at', 9), ('but', 9), ('its', 8), ('constitution', 8), ('pennsylvania', 8)]
#
# Now our most common 50 tokens (after removing stop words) are: [('states', 19), ('united', 15), ('government', 14), ('laws', 12), ('may', 12), ('would', 10), ('militia', 10), ('citizens', 9), ('constitution', 8), ('pennsylvania', 8), ('upon', 8), ('men', 7), ('congress', 7), ('every', 7), ('general', 6), ('power', 5), ('insurrection', 5), ('therefore', 5), ('let', 5), ('house', 4), ('however', 4), ('session', 4), ('counties', 4), ('justice', 4), ('might', 4), ('inspector', 4), ('time', 4), ('force', 4), ('without', 4), ('shall', 4), ('must', 4), ('thus', 4), ('army', 4), ('ought', 4), ('whether', 4), ('public', 4), ('fellow', 3), ('representatives', 3), ('nation', 3), ('prosperity', 3), ('order', 3), ('indeed', 3), ('far', 3), ('individuals', 3), ('execution', 3), ('officers', 3), ('certain', 3), ('could', 3), ('marshal', 3), ('office', 3)]

# %% [markdown]
# <h3 style='color:blue'>Exercises (Part I)</h3>
#
# <p style='color:blue'>10. Open and read in a different SOTU address of your choice. Tokenize it using the tokenizer we used to remove all punctuation.</p>

# %% [markdown]
# <p style='color:blue'>11. Now convert all remaining tokens into lower case and remove all stopwords. How many tokens are now found in your token list?</p>

# %% [markdown]
# <p style='color:blue'>13. Create a frequency list of the top 30 words in your new list of tokens (lowercase with all punctuation tokens and stopwords removed). Compare the frequency list to the list we created for Washington's 1794 address. In what ways do they appear most different? Similar?</p>

# %% [markdown]
# ## IV. Create a Dataframe of SOTU texts
#
# 14. To enable easier analysis of the SOTU texts, we can store info about each in a **dataframe**. Dataframes in Python are a common data structure enabled with the **pandas** library.

# %%
tokenizer = RegexpTokenizer(r'\w+')
#n=50

txtList=[]
pathlist = sotudir.glob('*.txt')       # .glob only stores the pathlist temporarily (for some reason), so you need to call it again!2
for path in pathlist:
    fn=path.stem                       #stem returns the filename minus the ".txt" (file extension). 
    year,pres=fn.split("_")            #1794_Washington" becomes year = "1794" and pres = "Washington"
    with open(path,'r') as f:  
        sotu = f.read()                #opens each file and reads it in as "sotu"
    tokens=tokenizer.tokenize(sotu)    # tokenizes "sotu"
    ltokens = [tok.lower() for tok in tokens]  #creates a lower case list called "ltokens"
    numtoks = len(ltokens)             # counts the number of tokens in "sotu"
    #tokfreqs=collections.Counter(ltokens)
    #wordFreq = tokfreqs[searchTerm]
    
    #print(wordFreq)
    txtList.append([pres,year,numtoks,tokens,sotu])   #add this info for "sotu" to a running list for all sotu addresses

colnames=['pres','year','numtoks','tokens','fulltext']
sotudf=pd.DataFrame(txtList,columns=colnames)  #places our completed list of SOTU info in a dataframe
sotudf.head(10)
# Out:
#          pres  year  numtoks  \
# 0  Washington  1790        0
# 1  Washington  1791     2314
# 2  Washington  1792     2104
# 3  Washington  1793     1973
# 4  Washington  1794     2918
# 5  Washington  1795     1988
# 6  Washington  1796     2878
# 7       Adams  1797     2060
# 8       Adams  1798     2218
# 9       Adams  1799     1505
#
#                                               tokens  \
# 0                                                 []
# 1  [Fellow, Citizens, of, the, Senate, and, House...
# 2  [Fellow, Citizens, of, the, Senate, and, House...
# 3  [Fellow, Citizens, of, the, Senate, and, House...
# 4  [Fellow, Citizens, of, the, Senate, and, House...
# 5  [Fellow, Citizens, of, the, Senate, and, House...
# 6  [Fellow, Citizens, of, the, Senate, and, House...
# 7  [Gentlemen, of, the, Senate, and, Gentlemen, o...
# 8  [Gentlemen, of, the, Senate, and, Gentlemen, o...
# 9  [Gentlemen, of, the, Senate, and, Gentlemen, o...
#
#                                             fulltext
# 0
# 1  Fellow-Citizens of the Senate and House of Rep...
# 2  Fellow-Citizens of the Senate and House of Rep...
# 3  Fellow-Citizens of the Senate and House of Rep...
# 4  Fellow-Citizens of the Senate and House of Rep...
# 5  Fellow-Citizens of the Senate and House of Rep...
# 6  Fellow-Citizens of the Senate and House of Rep...
# 7  Gentlemen of the Senate and Gentlemen of the H...
# 8  Gentlemen of the Senate and Gentlemen of the H...
# 9  Gentlemen of the Senate and Gentlemen of the H...

# %% [markdown]
# 15. It would be useful to reuse this dataframe in the future. Let's save it to a csv file.

# %%
sotudf.to_csv("sotudf.tsv",encoding = "utf-8",sep="\t")
#we are saving this with a "tsv" extension to indicate we are using tabs ("\t") as our delimiter between columns, not commas
#csv = comma separated values; tsv = tab separated values

# %% [markdown]
# ## V. Searching for Specific Words
#
# In this section, we will create code that searches for specific words across the entire SOTU corpus.
#
# 16. Before searching, however, we can quickly use the **concordance** function from the **nltk** library to view words in context.

# %%
text1 = nltk.Text(tokens) #remember, the tokens variable stores our first set of tokens derived from Washington's 1794 address
    ## for concordances, it makes sense to work with unmodified tokens (in original case with all words and punctuation
    ## still included)
text1.concordance("government")
# Out:
# Displaying 5 of 5 matches:
# ply because they could not afford government ordered health plans We repealed
# we know that faith and family not government and bureaucracy are the center of
#  their country And they deserve a Government that shows them the same love and
# st between our citizens and their Government Working with the Senate we are ap
#  to the world In Detroit I halted Government mandates that crippled America s

# %% [markdown]
# 17. Like a lot of Python functions, NLTK's **concordance**() functions allows us to pass in additional parameters. In this case, we will expand the context of our search terms to 200 characters.

# %%
text1.concordance("government",200)
# Out:
# Displaying 5 of 5 matches:
# an 50 000 a year forcing them to pay tremendous penalties simply because they could not afford government ordered health plans We repealed the core of disastrous Obamacare the individual mandate is no
# ag Together we are rediscovering the American way In America we know that faith and family not government and bureaucracy are the center of the American life Our motto is in God we trust And we celebr
# d why we proudly stand for the national anthem Americans love their country And they deserve a Government that shows them the same love and loyalty in return For the last year we have sought to restor
#  For the last year we have sought to restore the bonds of trust between our citizens and their Government Working with the Senate we are appointing judges who will interpret the Constitution as writte
#  ended the war on clean coal We are now an exporter of energy to the world In Detroit I halted Government mandates that crippled America s autoworkers so we can get the Motor City revving its engines

# %% [markdown]
# <h3 style = "color:purple">Python Basics: Writing Functions</h3>
#
# <p style="color:purple">18. Now, it would be helpful if we placed the above code into a small program or **function** so that we can easily search for other terms and plot their frequency.</p>
#
# <p style="color:purple">We have already used a variety of core Python functions such as <b>sum()</b>, <b>len()</b>, and <b>print()</b>. We have also called on many functions defined in auxiliary Python libraries or packages: such as the <b>word_tokenize()</b> and <b>concordance</b> functions from the <b>nltk</b> library we imported.</p>
#
# <p style="color:purple">Here, however, we will create our own function. The typical format of a Python function is:</p>
#
# ```python
# def functionName(argumentsToPassIn):
#     function instructions
#     return(resultsOfFunction)
# ```
#
# <p style="color:purple">19. So, for example, if we had a list of names and we wanted to create a function to retrieve the initial of each, we could use the following function:</p>

# %%
def Initials(fullname):
    caps = re.findall('([A-Z])', fullname) #this use sthe findall function from the re package to find all capitalized letters
    inits = ''.join(caps)  #takes our list of capitalized letters stored in "caps" and concatenates it
    return(inits)
    
fullname = "Jeremy M. Mikecz"     #replace w/ your name
Initials(fullname)
# Out:
# 'JMM'

# %% [markdown]
# <p style="color:purple">20. We can now apply this function to quickly return the initials from a long list of names.</p>

# %%
actorlist = ['Christoph Waltz','Tom Hardy','Doug Walker','Daryl Sabara','J.K. Simmons','Brad Garrett','Chris Hemsworth','Alan Rickman','Henry Cavill','Kevin Spacey','Giancarlo Giannini','Johnny Depp','Johnny Depp','Henry Cavill','Peter Dinklage','Chris Hemsworth','Johnny Depp','Will Smith','Aidan Turner','Emma Stone','Mark Addy','Aidan Turner','Christopher Lee','Naomi Watts','Leonardo DiCaprio','Robert Downey Jr.','Liam Neeson','Bryce Dallas Howard','Albert Finney','J.K. Simmons','Robert Downey Jr.','Johnny Depp','Hugh Jackman','Steve Buscemi','Glenn Morshower','Bingbing Li','Tim
is Quaid','Robin Wright','Steve Carell','Jon Hamm','Nicolas Cage','Peter Coyote','Peter Dinklage','Matthew McConaughey','Adam Sandler','Jennifer Garner','Will Ferrell','Raven-SymonÃ©','Mhairi Calvey','Jake Gyllenhaal','Albert Brooks','Martin Landau','Sylvester Stallone','David Gant','Bryce Dallas Howard','Oliver Platt','Rory Culkin','Rupert Everett','John Ratzenberger','Julia Roberts','Vin Diesel','Tim Conway','Lili Taylor','Michael Fassbender','Robin Williams','Dwayne Johnson','Bruce Willis','Jeremy Renner','Nicole Beharie','Tom Cruise','Bryce Dallas Howard','Sanaa Lathan','Amy Poehler','Jon Hamm']

# %%
for actor in actorlist:
    print(Initials(actor),"=",actor)
# Out:
# CW = Christoph Waltz
# TH = Tom Hardy
# DW = Doug Walker
# DS = Daryl Sabara
# JKS = J.K. Simmons
# BG = Brad Garrett
# CH = Chris Hemsworth
# AR = Alan Rickman
# HC = Henry Cavill
# KS = Kevin Spacey
# GG = Giancarlo Giannini
# JD = Johnny Depp
# JD = Johnny Depp
# HC = Henry Cavill
# PD = Peter Dinklage
# CH = Chris Hemsworth
# JD = Johnny Depp
# WS = Will Smith
# AT = Aidan Turner
# ES = Emma Stone
# MA = Mark Addy
# AT = Aidan Turner
# CL = Christopher Lee
# NW = Naomi Watts
# LDC = Leonardo DiCaprio
# RDJ = Robert Downey Jr.
# LN = Liam Neeson
# BDH = Bryce Dallas Howard
# AF = Albert Finney
# JKS = J.K. Simmons
# RDJ = Robert Downey Jr.
# JD = Johnny Depp
# HJ = Hugh Jackman
# SB = Steve Buscemi
# GM = Glenn Morshower
# BL = Bingbing Li
# TH = Tim Holmes
# ES = Emma Stone
# JB = Jeff Bridges
# JM = Joe Mantegna
# RR = Ryan Reynolds
# TH = Tom Hanks
# CB = Christian Bale
# JS = Jason Statham
# PC = Peter Capaldi
# JL = Jennifer Lawrence
# BC = Benedict Cumberbatch
# EM = Eddie Marsan
# LDC = Leonardo DiCaprio
# JG = Jake Gyllenhaal
# CH = Charlie Hunnam
# GM = Glenn Morshower
# HF = Harrison Ford
# AJB = A.J. Buckley
# KM = Kelly Macdonald
# SB = Sofia Boutella
# JR = John Ratzenberger
# TM = Tzi Ma
# OP = Oliver Platt
# RW = Robin Wright
# CT = Channing Tatum
# CW = Christoph Waltz
# JB = Jim Broadbent
# JL = Jennifer Lawrence
# CB = Christian Bale
# JR = John Ratzenberger
# AP = Amy Poehler
# RDJ = Robert Downey Jr.
# CGM = ChloÃ« Grace Moretz
# WS = Will Smith
# JL = Jet Li
# WS = Will Smith
# JB = Jimmy Bennett
# TC = Tom Cruise
# JT = Jeanne Tripplehorn
# JGL = Joseph Gordon-Levitt
# AP = Amy Poehler
# SJ = Scarlett Johansson
# RDJ = Robert Downey Jr.
# CH = Chris Hemsworth
# AJP = Angelina Jolie Pitt
# GO = Gary Oldman
# TE = Tamsin Egerton
# KR = Keanu Reeves
# SJ = Scarlett Johansson
# JH = Jon Hamm
# JG = Judy Greer
# DWJ = Damon Wayans Jr.
# JMB = Jack McBrayer
# TH = Tom Hanks
# VAF = Vivica A. Fox
# GB = Gerard Butler
# NS = Nick Stahl
# BC = Bradley Cooper
# MMC = Matthew McConaughey
# LDC = Leonardo DiCaprio
# MC = Mark Chinnery
# AT = Aidan Turner
# PW = Paul Walker
# BP = Brad Pitt
# JL = Jennifer Lawrence
# JL = Jennifer Lawrence
# NC = Nicolas Cage
# JB = Jimmy Bennett
# JD = Johnny Depp
# JT = Justin Timberlake
# DC = Dominic Cooper
# JKS = J.K. Simmons
# BS = Bruce Spence
# JG = Jennifer Garner
# ZW = Zack Ward
# AH = Anthony Hopkins
# RP = Robert Pattinson
# RP = Robert Pattinson
# WS = Will Smith
# WS = Will Smith
# JD = Johnny Depp
# JG = Janeane Garofalo
# CB = Christian Bale
# BM = Bernie Mac
# RW = Robin Williams
# HJ = Hugh Jackman
# ED = Essie Davis
# JG = Josh Gad
# SB = Steve Bastoni
# CH = Chris Hemsworth
# TH = Tom Hardy
# TH = Tom Hanks
# CH = Chris Hemsworth
# CGM = ChloÃ« Grace Moretz
# KG = Kelli Garner
# LN = Liam Neeson
# JD = Johnny Depp
# TC = Tom Cruise
# AH = Anthony Hopkins
# CW = Christoph Waltz
# MB = Matthew Broderick
# AJP = Angelina Jolie Pitt
# SG = Seychelle Gabriel
# PSH = Philip Seymour Hoffman
# CT = Channing Tatum
# EH = Elisabeth Harnois
# HJ = Hugh Jackman
# HJ = Hugh Jackman
# TB = Ty Burrell
# BP = Brad Pitt
# JPS = Jada Pinkett Smith
# TS = Toby Stephens
# EBJ = Ed Begley Jr.
# BW = Bruce Willis
# WS = Will Smith
# RW = Robin Wright
# JKS = J.K. Simmons
# TC = Tom Cruise
# HJ = Hugh Jackman
# JMH = John Michael Higgins
# TC = Tom Cruise
# CB = Christian Bale
# CH = Chris Hemsworth
# JKS = J.K. Simmons
# GB = Gerard Butler
# GB = Gerard Butler
# SS = Sam Shepard
# MF = Matt Frewer
# JL = Jet Li
# KR = Kevin Rankin
# CT = Channing Tatum
# MMC = Matthew McConaughey
# SB = Steve Buscemi
# CE = Chris Evans
# CS = Colin Salmon
# JDA = James DArcy
# RP = Robert Pattinson
# RW = Robin Williams
# TB = Ty Burrell
# DJ = Don Johnson
# MR = Mark Rylance
# LDC = Leonardo DiCaprio
# RR = Ryan Reynolds
# JD = Johnny Depp
# BC = Benedict Cumberbatch
# MD = Matt Damon
# AJP = Angelina Jolie Pitt
# JG = Judy Greer
# JL = Jennifer Lawrence
# RP = Robert Pattinson
# JP = Jim Parsons
# TC = Tom Cruise
# WS = Will Smith
# SH = Salma Hayek
# AJP = Angelina Jolie Pitt
# AH = Anthony Hopkins
# TJ = Toby Jones
# DR = Daniel Radcliffe
# ED = Essie Davis
# WS = Will Smith
# AW = Alfre Woodard
# RG = Rupert Grint
# RW = Robin Williams
# JKS = J.K. Simmons
# DR = Daniel Radcliffe
# RR = Ryan Reynolds
# MC = Mark Chinnery
# JD = Johnny Depp
# RG = Rupert Grint
# JL = Jennifer Lawrence
# TH = Tom Hanks
# MF = Miguel Ferrer
# HJ = Hugh Jackman
# PW = Paul Walker
# RDJ = Robert Downey Jr.
# LN = Liam Neeson
# RC = Ronny Cox
# TC = Tony Curran
# JR = Jeremy Renner
# MG = Michael Gough
# CH = Clint Howard
# JG = Jake Gyllenhaal
# TC = Tom Cruise
# KA = Karen Allen
# CE = Chris Evans
# SS = Suraj Sharma
# NC = Nicolas Cage
# MD = Matt Damon
# DM = Demi Moore
# MF = Michael Fassbender
# NL = Nathan Lane
# MD = Matt Damon
# VD = Vin Diesel
# GO = Gary Oldman
# SP = Scott Porter
# SC = Shelley Conn
# TC = Tom Cruise
# MF = Morgan Freeman
# NP = Natalie Portman
# NP = Natalie Portman
# SB = Steve Buscemi
# HJ = Hugh Jackman
# NP = Natalie Portman
# RR = Ryan Reynolds
# AD = Alain Delon
# NC = Nicolas Cage
# CH = Chris Hemsworth
# NF = Noel Fisher
# PS = Phaldut Sharma
# JRS = Jamie RenÃ©e Smith
# SA = Stephen Amell
# TBN = Tim Blake Nelson
# RW = Robin Williams
# DJ = Dwayne Johnson
# VS = Vincent Schiavelli
# HL = Heath Ledger
# BP = Brad Pitt
# BP = Brad Pitt
# KW = Kate Winslet
# LDC = Leonardo DiCaprio
# JC = James Corden
# CW = Christoph Waltz
# GP = George Peppard
# EG = Eva Green
# MS = Mahadeo Shivraj
# SB = Steve Buscemi
# NW = Naomi Watts
# HJ = Hugh Jackman
# JT = Jacob Tremblay
# JP = Jason Patric
# HF = Harrison Ford
# BW = Bruce Willis
# CL = Christopher Lee
# JB = Jim Broadbent
# WS = Will Smith
# SH = Sean Hayes
# WS = Will Smith
# LN = Liam Neeson
# CP = Chazz Palminteri
# OW = Oprah Winfrey
# MD = Matt Damon
# MB = Mathew Buck
# SJ = Scarlett Johansson
# DZ = Del Zamora
# NC = Nicolas Cage
# DH = Djimon Hounsou
# TC = Tom Cruise
# DR = Daniel Radcliffe
# EG = Eva Green
# CHT = Cary-Hiroyuki Tagawa
# JM = Joe Morton
# JD = Johnny Depp
# DW = Denzel Washington
# JLC = Jamie Lee Curtis
# DW = Denzel Washington
# RDN = Robert De Niro
# DJ = Dwayne Johnson
# VW = Vanessa Williams
# LDC = Leonardo DiCaprio
# DM = Demi Moore
# EK = Eartha Kitt
# JS = Jason Statham
# NC = Nicolas Cage
# DH = Djimon Hounsou
# COH = Catherine OHara
# HJ = Hugh Jackman
# JH = Josh Hutcherson
# JD = Johnny Depp
# CCHP = CCH Pounder
# LDC = Leonardo DiCaprio
# LDC = Leonardo DiCaprio
# MG = Michael Gough
# JB = Jake Busey
# TH = Tom Hanks
# AC = Abbie Cornish
# FC = Frances Conroy
# DJ = Dwayne Johnson
# JGL = Joseph Gordon-Levitt
# WF = Will Ferrell
# JS = Jason Statham
# RW = Ray Winstone
# JK = Jamie Kennedy
# CH = Chris Hemsworth
# RD = Rosario Dawson
# MD = Matt Damon
# FC = Francesca Capaldi
# BG = Ben Gazzara
# DJ = Dwayne Johnson
# LDC = Leonardo DiCaprio
# CB = Christian Bale
# JB = Jeff Bridges
# JL = Jon Lovitz
# IG = Ioan Gruffudd
# WF = Will Ferrell
# MJ = Milla Jovovich
# CN = Chris Noth
# FW = Frank Welker
# PD = Peter Dinklage
# HA = Hayley Atwell
# MI = Michael Imperioli
# AG = Alexander Gould
# OB = Orlando Bloom
# CL = Christopher Lee
# JB = Jeff Bridges
# AJP = Angelina Jolie Pitt
# JD = Johnny Depp
# MJ = Michael Jeter
# JF = James Franco
# MS = Martin Short
# BW = Bruce Willis
# DQ = Dennis Quaid
# HH = Holly Hunter
# CM = Christopher Masterson
# LL = Logan Lerman
# WS = Will Smith
# TH = Tom Hanks
# DW = Denzel Washington
# MM = Mei MelanÃ§on
# HF = Harrison Ford
# WF = Will Forte
# DL = Denis Leary
# AS = Adam Scott
# BM = Bill Murray
# LDC = Leonardo DiCaprio
# MNW = Ming-Na Wen
# RDJ = Robert Downey Jr.
# RW = Robin Wright
# BW = Bruce Willis
# RDJ = Robert Downey Jr.
# MF = Morgan Freeman
# LN = Leonard Nimoy
# BT = Bella Thorne
# TC = Tom Cruise
# AS = Adam Sandler
# PD = Peter Dinklage
# HJO = Haley Joel Osment
# MT = Marsha Thomason
# MMC = Matthew McConaughey
# GG = Greg Grunberg
# CC = Curtiss Cook
# LL = Logan Lerman
# GB = Gerard Butler
# DR = Daniel Radcliffe
# AA = Alun Armstrong
# BP = Brad Pitt
# DC = Don Cheadle
# AH = Anne Hathaway
# RW = Robin Williams
# DC = Don Cheadle
# HF = Harrison Ford
# LN = Liam Neeson
# TBN = Tim Blake Nelson
# WS = William Smith
# PC = Paddy Considine
# SH = Shirley Henderson
# JB = Jeff Bridges
# PSH = Philip Seymour Hoffman
# PW = Paul Walker
# TH = Tom Hanks
# RW = Robin Williams
# MD = Matt Damon
# HF = Harrison Ford
# BP = Brad Pitt
# MJ = Milla Jovovich
# SB = Steve Buscemi
# JB = Jeff Bennett
# CD = Caroline Dhavernas
# DW = Denzel Washington
# IG = Ioan Gruffudd
# MB = Matthew Broderick
# KW = Kate Winslet
# WS = Will Smith
# MS = Meryl Streep
# AP = Al Pacino
# JF = Jon Favreau
# KW = Kate Winslet
# BH = Bob Hoskins
# DJ = Dwayne Johnson
# FMA = F. Murray Abraham
# LG = Li Gong
# ASW = Amber Stevens West
# JB = Jim Broadbent
# AH = Anthony Hopkins
# RC = Raymond Cruz
# RS = Roy Scheider
# JR = Julia Roberts
# AK = Anna Kendrick
# GM = Glenn Morshower
# LM = Larry Miller
# SMG = Sarah Michelle Gellar
# WH = Wood Harris
# AS = Adam Sandler
# TD = Ted Danson
# JMB = Jack McBrayer
# KS = Kristen Stewart
# SMF = Seth MacFarlane
# RDJ = Robert Downey Jr.
# RD = Robert Duvall
# MF = Morgan Freeman
# JS = Jason Statham
# TC = Tom Cruise
# JL = Jennifer Lawrence
# BC = Bradley Cooper
# MG = Michael Gough
# BW = Bruce Willis
# TC = Tia Carrere
# SB = Steve Buscemi
# MF = Morgan Freeman
# BW = Bruce Willis
# AS = Adam Sandler
# AP = Amy Poehler
# SB = Steve Buscemi
# BM = Bill Murray
# KR = Keanu Reeves
# LDC = Leonardo DiCaprio
# JF = Jon Favreau
# JB = Jim Broadbent
# NC = Nicolas Cage
# AS = Adam Sandler
# TH = Tom Hanks
# AS = Adam Sandler
# EH = Elden Henson
# SB = Steve Buscemi
# RD = Rosario Dawson
# PSH = Philip Seymour Hoffman
# DW = Denzel Washington
# RW = Robin Williams
# LN = Liam Neeson
# BM = Bill Murray
# RR = Roger Rees
# KR = Keanu Reeves
# JR = Julia Roberts
# BP = Brad Pitt
# HF = Harrison Ford
# JT = Justin Timberlake
# MD = Matt Damon
# RD = Rosario Dawson
# GO = Gary Oldman
# DW = Denzel Washington
# VR = Vanessa Redgrave
# SB = Steve Buscemi
# EM = Elizabeth Montgomery
# QJ = Quincy Jones
# MA = Mark Addy
# CT = Charlize Theron
# HJ = Hugh Jackman
# ME = Michael Emerson
# RW = Robin Williams
# AS = Adam Sandler
# MD = Matt Damon
# NP = Natalie Portman
# NR = Nissim Renard
# AH = Anthony Hopkins
# BW = Bruce Willis
# BG = Bruce Greenwood
# SS = Sylvester Stallone
# CR = Charlie Rowe
# RT = Richard Tyson
# BF = Brendan Fraser
# F = Fergie
# PW = Paul Walker
# OW = Olivia Williams
# AG = Adam Goldberg
# VD = Vin Diesel
# BN = Bob Neill
# MF = Mia Farrow
# PAJ = Pedro ArmendÃ¡riz Jr.
# DO = David Oyelowo
# SR = Sasha Roiz
# SM = Sariann Monaco
# AG = Adam Goldberg
# MB = Matthew Broderick
# JH = Josh Hutcherson
# WF = Will Forte
# PSH = Philip Seymour Hoffman
# JKS = J.K. Simmons
# AP = Al Pacino
# PW = Paul Walker
# JB = Jeff Bridges
# RR = Roger Rees
# RDN = Robert De Niro
# SC = Steve Coogan
# JF = Jason Flemyng
# SC = Steve Carell
# WS = Will Smith
# AR = Ariana Richards
# JPS = Jada Pinkett Smith
# CH = Charlie Hunnam
# HJ = Hugh Jackman
# AJP = Angelina Jolie Pitt
# NC = Nicolas Cage
# DL = Denis Leary
# AS = Adam Sandler
# JS = Jerry Stiller
# JDA = James DArcy
# MB = Matthew Broderick
# MF = Morgan Freeman
# SB = Steve Buscemi
# TH = Tom Hanks
# HP = Harold Perrineau
# DC = Don Cheadle
# NL = Nicholas Lea
# PSH = Philip Seymour Hoffman
# RDN = Robert De Niro
# LD = Loretta Devine
# AA = Adam Arkin
# DJ = Dwayne Johnson
# AZ = Ayelet Zurer
# BW = Bruce Willis
# TS = Tom Selleck
# HC = Henry Cavill
# AS = Adam Sandler
# SB = Steve Buscemi
# BW = Bruce Willis
# JO = Julia Ormond
# BL = Bai Ling
# HC = Henry Cavill
# JB = Jimmy Bennett
# MD = Matt Damon
# HF = Harrison Ford
# CN = Connie Nielsen
# CM = Christopher Meloni
# BF = Brendan Fraser
# DQ = Dennis Quaid
# RW = Robin Wright
# SC = Steve Carell
# JH = Jon Hamm
# NC = Nicolas Cage
# PC = Peter Coyote
# PD = Peter Dinklage
# MMC = Matthew McConaughey
# AS = Adam Sandler
# JG = Jennifer Garner
# WF = Will Ferrell
# RS = Raven-SymonÃ©
# MC = Mhairi Calvey
# JG = Jake Gyllenhaal
# AB = Albert Brooks
# ML = Martin Landau
# SS = Sylvester Stallone
# DG = David Gant
# BDH = Bryce Dallas Howard
# OP = Oliver Platt
# RC = Rory Culkin
# RE = Rupert Everett
# JR = John Ratzenberger
# JR = Julia Roberts
# VD = Vin Diesel
# TC = Tim Conway
# LT = Lili Taylor
# MF = Michael Fassbender
# RW = Robin Williams
# DJ = Dwayne Johnson
# BW = Bruce Willis
# JR = Jeremy Renner
# NB = Nicole Beharie
# TC = Tom Cruise
# BDH = Bryce Dallas Howard
# SL = Sanaa Lathan
# AP = Amy Poehler
# JH = Jon Hamm

# %% [markdown]
# Now, we are going to search across the entire SOTU corpus for a particular search term, count its frequency in each text, and then store that count in a dataframe.
#
# 21. First, we will apply a function to search for a term within a specific tokenized list.

# %%
def getWordFreq (term,toks):
    ltoks = [tok.lower() for tok in toks]
    tokfreqs=collections.Counter(ltoks)
    wordFreq = tokfreqs[term]
    return(wordFreq)

# %%
searchTerm = "government"
#to apply to one text
print(getWordFreq(searchTerm,tokens2))
# Out:
# 14

# %%
sotudf.head()
# Out:
#          pres  year  numtoks  \
# 0  Washington  1790        0
# 1  Washington  1791     2314
# 2  Washington  1792     2104
# 3  Washington  1793     1973
# 4  Washington  1794     2918
#
#                                               tokens  \
# 0                                                 []
# 1  [Fellow, Citizens, of, the, Senate, and, House...
# 2  [Fellow, Citizens, of, the, Senate, and, House...
# 3  [Fellow, Citizens, of, the, Senate, and, House...
# 4  [Fellow, Citizens, of, the, Senate, and, House...
#
#                                             fulltext
# 0
# 1  Fellow-Citizens of the Senate and House of Rep...
# 2  Fellow-Citizens of the Senate and House of Rep...
# 3  Fellow-Citizens of the Senate and House of Rep...
# 4  Fellow-Citizens of the Senate and House of Rep...

# %%
#to apply to a dataframe full of texts:
sotudf['wordFreq'] = sotudf['tokens'].apply(lambda x: getWordFreq(searchTerm,x))
sotudf.head()
# Out:
#          pres  year  numtoks  \
# 0  Washington  1790        0
# 1  Washington  1791     2314
# 2  Washington  1792     2104
# 3  Washington  1793     1973
# 4  Washington  1794     2918
#
#                                               tokens  \
# 0                                                 []
# 1  [Fellow, Citizens, of, the, Senate, and, House...
# 2  [Fellow, Citizens, of, the, Senate, and, House...
# 3  [Fellow, Citizens, of, the, Senate, and, House...
# 4  [Fellow, Citizens, of, the, Senate, and, House...
#
#                                             fulltext  wordFreq
# 0                                                            0
# 1  Fellow-Citizens of the Senate and House of Rep...         7
# 2  Fellow-Citizens of the Senate and House of Rep...         3
# 3  Fellow-Citizens of the Senate and House of Rep...         3
# 4  Fellow-Citizens of the Senate and House of Rep...        14

# %%
sotudf['freq_perMillion'] = sotudf['wordFreq']/sotudf['numtoks']*1000000
# %%
print(searchTerm)
sns.barplot(data=sotudf2, x="year", y="freq_perMillion"); #adding the ";" removes the annoying text that Python sometimes prints out with a graphic
# Out:
# government

# %% [markdown]
# 24. Below, I copied the code from **Step 14**, but this time placed into a function. *Note: all code within a function must be indented. Once the indentation ends, so does the function.*

# %%
def sotuWordSearch(searchTerm):
    pathlist = sotudir.glob('*.txt') # .glob only stores the pathlist temporarily (for some reason), so you need to call it again!2
    txtList = []
    for path in pathlist:
        fn=path.stem
        year,pres=fn.split("_")
        with open(path,'r') as f:  
            sotu = f.read()
        tokens=tokenizer.tokenize(sotu)
        ltokens = [tok.lower() for tok in tokens]
        numtoks = len(ltokens)
        tokfreqs=collections.Counter(ltokens)
        wordFreq = tokfreqs[searchTerm]
        txtList.append([pres,year,wordFreq,numtoks,tokens])
    
    colnames=['pres','year','wordFreq','numtoks','tokens']
    sotudf=pd.DataFrame(txtList,columns=colnames)  ##
    sotudf["presnum"] = (sotudf["pres"] != sotudf["pres"].shift()).cumsum()
    sotudf2 = sotudf.groupby(['pres','presnum']).agg({'wordFreq':'sum','numtoks':'sum','year':'first'})
    sotudf2['freq_perMillion'] = sotudf2['wordFreq'] / sotudf2['numtoks'] * 1000000
    sotudf2 = sotudf2.sort_values(['year'])
    sotudf2 = sotudf2.reset_index()
    print("searching for... :",searchTerm)
    return(sotudf2)

# %%
#NOT NECESSARY??
#def searchOneText(ltoks,searchTerm): #searches for a lower-case term in a list of lower-case tokens, returns its freq.
#    numtoks = len(ltoks)
#    tokfreqs=collections.Counter(ltokens)
#    wordFreq = tokfreqs[searchTerm]
#    return(wordFreq)

def sotuWordSearch2(ltoksCol,searchTerm): #returns a column of frequencies after searching for a term across a column of lower-case tokens
    #searchTerm = searchTerm.lower()
    wordFreq = ltoksCol.apply(lambda x:collections.Counter(x)[searchTerm])
    return(wordFreq)

def df_wordFreqCalc(old_df,searchTerm):
    requiredCols = ['ltoks','numtoks','pres','presnum','year']
    if not set(requiredCols).issubset(old_df.columns):
        print("missing required column from:",requiredCols)
        return None
    new_df = old_df.groupby(['pres','presnum']).agg({'wordFreq':'sum','numtoks':'sum','year':'first'})
    new_df['freq_perMillion'] = new_df['wordFreq'] / new_df['numtoks'] * 1000000
    new_df = new_df.sort_values(['year'])
    new_df = new_df.reset_index()
    print("searching for... :",searchTerm)
    return(new_df)

# %%
searchTerm = "freedom"
sotudf3 = df_wordFreqCalc(sotudf,searchTerm)
print(sotudf3.head(15))
# Out:
# searching for... : freedom
#           pres  presnum  wordFreq  numtoks  year  freq_perMillion
# 0   Washington        1        40    14175  1790      2821.869489
# 1        Adams        2        21     7157  1797      2934.190303
# 2    Jefferson        3        34    20743  1801      1639.107169
# 3      Madison        4        62    21738  1809      2852.148312
# 4       Monroe        5       167    42512  1817      3928.302597
# 5        Adams        6        61    31405  1825      1942.365865
# 6      Jackson        7       436    85570  1829      5095.243660
# 7        Buren        8       256    45594  1837      5614.773874
# 8        Tyler        9       209    34192  1841      6112.540945
# 9         Polk       10       332    72643  1845      4570.295830
# 10      Taylor       11        35     7666  1849      4565.614401
# 11    Fillmore       12       135    31799  1850      4245.416523
# 12      Pierce       13       182    42130  1853      4319.962022
# 13    Buchanan       14       279    56938  1857      4900.066739
# 14     Lincoln       15        75    27947  1861      2683.651197

# %%
sotudf['ltoks'] = sotudf['tokens'].apply(lambda x: [tok.lower() for tok in x])

searchTerm = "government"
sotudf['wordFreq'] = sotuWordSearch(sotudf['ltoks'], searchTerm)

# %%
sotudf2 = sotudf.groupby(['pres','presnum']).agg({'wordFreq':'sum','numtoks':'sum','year':'first'})
sotudf2['freq_perMillion'] = sotudf2['wordFreq'] / sotudf2['numtoks'] * 1000000
sotudf2 = sotudf2.sort_values(['year'])
sotudf2 = sotudf2.reset_index()
sotudf.head(15)
# Out:
#           pres  year  numtoks  \
# 0   Washington  1790        0
# 1   Washington  1791     2314
# 2   Washington  1792     2104
# 3   Washington  1793     1973
# 4   Washington  1794     2918
# 5   Washington  1795     1988
# 6   Washington  1796     2878
# 7        Adams  1797     2060
# 8        Adams  1798     2218
# 9        Adams  1799     1505
# 10       Adams  1800     1374
# 11   Jefferson  1801     3226
# 12   Jefferson  1802     2209
# 13   Jefferson  1803     2283
# 14   Jefferson  1804     2108
#
#                                                tokens  \
# 0                                                  []
# 1   [Fellow, Citizens, of, the, Senate, and, House...
# 2   [Fellow, Citizens, of, the, Senate, and, House...
# 3   [Fellow, Citizens, of, the, Senate, and, House...
# 4   [Fellow, Citizens, of, the, Senate, and, House...
# 5   [Fellow, Citizens, of, the, Senate, and, House...
# 6   [Fellow, Citizens, of, the, Senate, and, House...
# 7   [Gentlemen, of, the, Senate, and, Gentlemen, o...
# 8   [Gentlemen, of, the, Senate, and, Gentlemen, o...
# 9   [Gentlemen, of, the, Senate, and, Gentlemen, o...
# 10  [Gentlemen, of, the, Senate, and, Gentlemen, o...
# 11  [Fellow, Citizens, of, the, Senate, and, House...
# 12  [To, the, Senate, and, House, of, Representati...
# 13  [To, The, Senate, and, House, of, Representati...
# 14  [The, Senate, and, House, of, Representatives,...
#
#                                              fulltext  presnum  numUniq  \
# 0                                                            1        0
# 1   Fellow-Citizens of the Senate and House of Rep...        1      811
# 2   Fellow-Citizens of the Senate and House of Rep...        1      764
# 3   Fellow-Citizens of the Senate and House of Rep...        1      798
# 4   Fellow-Citizens of the Senate and House of Rep...        1     1133
# 5   Fellow-Citizens of the Senate and House of Rep...        1      814
# 6   Fellow-Citizens of the Senate and House of Rep...        1      998
# 7   Gentlemen of the Senate and Gentlemen of the H...        2      727
# 8   Gentlemen of the Senate and Gentlemen of the H...        2      827
# 9   Gentlemen of the Senate and Gentlemen of the H...        2      593
# 10  Gentlemen of the Senate and Gentlemen of the H...        2      557
# 11  Fellow Citizens of the Senate and House of Rep...        3     1095
# 12  To the Senate and House of Representatives:\n\...        3      817
# 13  To The Senate and House of Representatives of ...        3      833
# 14  The Senate and House of Representatives of the...        3      741
#
#       lexdiv                                              ltoks  wordFreq  \
# 0   0.000000                                                 []         0
# 1   0.350475  [fellow, citizens, of, the, senate, and, house...         7
# 2   0.363118  [fellow, citizens, of, the, senate, and, house...         3
# 3   0.404460  [fellow, citizens, of, the, senate, and, house...         3
# 4   0.388280  [fellow, citizens, of, the, senate, and, house...        14
# 5   0.409457  [fellow, citizens, of, the, senate, and, house...         4
# 6   0.346769  [fellow, citizens, of, the, senate, and, house...         9
# 7   0.352913  [gentlemen, of, the, senate, and, gentlemen, o...         2
# 8   0.372858  [gentlemen, of, the, senate, and, gentlemen, o...         6
# 9   0.394020  [gentlemen, of, the, senate, and, gentlemen, o...         8
# 10  0.405386  [gentlemen, of, the, senate, and, gentlemen, o...         5
# 11  0.339430  [fellow, citizens, of, the, senate, and, house...         7
# 12  0.369851  [to, the, senate, and, house, of, representati...         1
# 13  0.364871  [to, the, senate, and, house, of, representati...         6
# 14  0.351518  [the, senate, and, house, of, representatives,...         7
#
#     wordFreq2
# 0           0
# 1           7
# 2           3
# 3           3
# 4          14
# 5           4
# 6           9
# 7           2
# 8           6
# 9           8
# 10          5
# 11          7
# 12          1
# 13          6
# 14          7

# %% [markdown]
# 25. Now we can choose a new search term and call that function to return a dataframe with the results of this search.

# %%
term = "freedom"
searchdf = sotuWordSearch(term)
print(df.tail(10))
# Out:
# searching for... : freedom
#        pres  presnum  wordFreq  numtoks  year  freq_perMillion
# 33  Johnson       34        25    29422  1964       849.704303
# 34    Nixon       35        14    19952  1970       701.684042
# 35     Ford       36         8    13908  1975       575.208513
# 36   Carter       37        16    45591  1978       350.946459
# 37   Reagan       38        93    33031  1982      2815.536920
# 38     Bush       39        32    17530  1989      1825.442099
# 39  Clinton       40        30    60117  1993       499.026898
# 40     Bush       41        83    40867  2001      2030.978540
# 41    Obama       42        11    53807  2009       204.434367
# 42    Trump       43         9    10299  2017       873.871250

# %% [markdown]
# 26. Create a simple graph from this search.

# %%
g=sns.barplot(data=df, x="presnum",y="freq_perMillion")
g.tick_params(labelrotation=90)

# %% [markdown]
# 27. What additions would make this plot more useful?

# %%
g=sns.barplot(data=df, x="presnum",y="freq_perMillion")
g.tick_params(labelrotation=90)
g.set(title = "Frequency of '%s' in State of the Union Addresses"%term)
g.set(ylabel='per million words', xlabel='President')
g.set(xticklabels = df.pres);

# %%
term = "war"
df = sotuWordSearch(term)
g=sns.barplot(data=df, x="presnum",y="freq_perMillion")
g.tick_params(labelrotation=90)
g.set(title = "Frequency of '%s' in State of the Union Addresses"%term)
g.set(ylabel='per million words', xlabel='President')
g.set(xticklabels = df.pres);
# Out:
# searching for... : war

# %%
# save this image
fig = g.get_figure()
fig.savefig('sotuSearch_%s.png'%term)

# %% [markdown]
# ## Part VII: NGrams

# %% [markdown]
# 26. Often, in searching for patterns in texts, single words are not the most useful units of analysis. Instead, at times, the frequency of multiple-word terms may be more instructive. For example, historians mining historical scholarship may be interested in the rise and fall of sub-disciplines in his/her field, such as "social history", "cultural history", "environmental history", etc. In this case, the historian may want to examine patterns in two-word combinations, called **bigrams**. In other cases, it may be useful to examine three-, four-, or five-word combinations, called **ngrams**.
#
# First, we will extract ngrams from a simple phrase:

# %%
text = "to be or not to be"
toks = nltk.word_tokenize(text) 
print(toks)
# Out:
# ['to', 'be', 'or', 'not', 'to', 'be']

# %%
n = 2
n_grams=list(ngrams(toks,n))
print(n_grams)
# Out:
# [('to', 'be'), ('be', 'or'), ('or', 'not'), ('not', 'to'), ('to', 'be')]

# %% [markdown]
# 27. Now let us create a list of ngrams from a SOTU address. We can retrieve a list of tokens from our sotudf dataframe.

# %%
pres = "Eisenhower"
year = "1956"
#the line below extracts the tokens for just one SOTU address (specified with the pres and year variables)
toks = sotudf.loc[(sotudf['pres'] == pres) & (sotudf['year'] == year)]['tokens'].values[0]
print(toks)
# Out:
# ['To', 'the', 'Congress', 'of', 'the', 'United', 'States', 'The', 'opening', 'of', 'this', 'new', 'year', 'must', 'arouse', 'in', 'us', 'all', 'grateful', 'thanks', 'to', 'a', 'kind', 'Providence', 'whose', 'protection', 'has', 'been', 'ever', 'present', 'and', 'whose', 'bounty', 'has', 'been', 'manifold', 'and', 'abundant', 'The', 'State', 'of', 'the', 'Union', 'today', 'demonstrates', 'what', 'can', 'be', 'accomplished', 'under', 'God', 'by', 'a', 'free', 'people', 'by', 'their', 'vision', 'their', 'understanding', 'of', 'national', 'problems', 'their', 'initiative', 'their', 'self', 'reliance', 'their', 'capacity', 'for', 'work', 'and', 'by', 'their', 'willingness', 'to', 'sacrifice', 'whenever', 'sacrifice', 'is', 'needed', 'In', 'the', 'past', 'three', 'years', 'responding', 'to', 'what', 'our', 'people', 'want', 'their', 'Government', 'to', 'do', 'the', 'Congress', 'and', 'the', 'Executive', 'have', 'done', 'much', 'in', 'building', 'a', 'stronger', 'better', 'America', 'There', 'has', 'been', 'broad', 'progress', 'in', 'fostering', 'the', 'energies', 'of', 'our', 'people', 'in', 'providing', 'greater', 'opportunity', 'for', 'the', 'satisfaction', 'of', 'their', 'needs', 'and', 'in', 'fulfilling', 'their', 'demands', 'for', 'the', 'strength', 'and', 'security', 'of', 'the', 'Republic', 'Our', 'country', 'is', 'at', 'peace', 'Our', 'security', 'posture', 'commands', 'respect', 'A', 'spiritual', 'vigor', 'marks', 'our', 'national', 'life', 'Our', 'economy', 'approaching', 'the', '400', 'billion', 'dollar', 'mark', 'is', 'at', 'an', 'unparalleled', 'level', 'of', 'prosperity', 'The', 'national', 'income', 'is', 'more', 'widely', 'and', 'fairly', 'distributed', 'than', 'ever', 'before', 'The', 'number', 'of', 'Americans', 'at', 'work', 'has', 'reached', 'an', 'all', 'time', 'high', 'As', 'a', 'people', 'we', 'are', 'achieving', 'ever', 'higher', 'standards', 'of', 'living', 'earning', 'more', 'producing', 'more', 'consuming', 'more', 'building', 'more', 'and', 'investing', 'more', 'than', 'ever', 'before', 'Virtually', 'all', 'sectors', 'of', 'our', 'society', 'are', 'sharing', 'in', 'these', 'good', 'times', 'Our', 'farm', 'families', 'if', 'we', 'act', 'wisely', 'imaginatively', 'and', 'promptly', 'to', 'strengthen', 'our', 'present', 'farm', 'programs', 'can', 'also', 'look', 'forward', 'to', 'sharing', 'equitably', 'in', 'the', 'prosperity', 'they', 'have', 'helped', 'to', 'create', 'War', 'in', 'Korea', 'ended', 'two', 'and', 'a', 'half', 'years', 'ago', 'The', 'collective', 'security', 'system', 'has', 'been', 'powerfully', 'strengthened', 'Our', 'defenses', 'have', 'been', 'reinforced', 'at', 'sharply', 'reduced', 'costs', 'Programs', 'to', 'expand', 'world', 'trade', 'and', 'to', 'harness', 'the', 'atom', 'for', 'the', 'betterment', 'of', 'mankind', 'have', 'been', 'carried', 'forward', 'Our', 'economy', 'has', 'been', 'freed', 'from', 'governmental', 'wage', 'and', 'price', 'controls', 'Inflation', 'has', 'been', 'halted', 'the', 'cost', 'of', 'living', 'stabilized', 'Government', 'spending', 'has', 'been', 'cut', 'by', 'more', 'than', 'ten', 'billion', 'dollars', 'Nearly', 'three', 'hundred', 'thousand', 'positions', 'have', 'been', 'eliminated', 'from', 'the', 'Federal', 'payroll', 'Taxes', 'have', 'been', 'substantially', 'reduced', 'A', 'balanced', 'budget', 'is', 'in', 'prospect', 'Social', 'security', 'has', 'been', 'extended', 'to', 'ten', 'million', 'more', 'Americans', 'and', 'unemployment', 'insurance', 'to', 'four', 'million', 'more', 'Unprecedented', 'advances', 'in', 'civil', 'rights', 'have', 'been', 'made', 'The', 'long', 'standing', 'and', 'deep', 'seated', 'problems', 'of', 'agriculture', 'have', 'been', 'forthrightly', 'attacked', 'This', 'record', 'of', 'progress', 'has', 'been', 'accomplished', 'with', 'a', 'self', 'imposed', 'caution', 'against', 'unnecessary', 'and', 'unwise', 'interference', 'in', 'the', 'private', 'affairs', 'of', 'our', 'people', 'of', 'their', 'communities', 'and', 'of', 't ...

# %%
ltoks = [tok.lower() for tok in toks]
n = 3                                  #n sets the number of words in phrase we will search for
n_gramslower = list(ngrams(ltoks,n))
n_grams = list(ngrams(toks,n))
ng_freqslower = collections.Counter(n_gramslower)
ng_freqs = collections.Counter(n_grams)
print(ng_freqslower.most_common(10),"\n\n***\n")
print(ng_freqs.most_common(10))
# Out:
# [(('to', 'the', 'congress'), 11), (('the', 'united', 'states'), 9), (('of', 'the', 'united'), 7), (('of', 'our', 'people'), 6), (('will', 'be', 'submitted'), 6), (('submitted', 'to', 'the'), 6), (('the', 'administration', 'will'), 6), (('past', 'three', 'years'), 5), (('be', 'submitted', 'to'), 5), (('the', 'free', 'world'), 5)]
#
# ***
#
# [(('to', 'the', 'Congress'), 10), (('the', 'United', 'States'), 8), (('of', 'the', 'United'), 7), (('of', 'our', 'people'), 6), (('will', 'be', 'submitted'), 6), (('submitted', 'to', 'the'), 6), (('past', 'three', 'years'), 5), (('be', 'submitted', 'to'), 5), (('the', 'free', 'world'), 5), (('The', 'Administration', 'will'), 5)]

# %% [markdown]
# <h3 style = "color:blue">Exercises</h3>
#
# <p style = "color:blue">Create a ngram frequency list for another SOTU address.</p>

# %% [markdown]
# For ngrams, do we want to keep stopwords? Describing a person, for example, as "the leader" rather than "a leader" makes a significant difference. Thus, let's first try working with *ltokens2* below.

# %% [markdown]
# ## Part VIII: Visualizing Word Patterns - Comparing Multiple Words
#
# ### Dispersion Plots, Frequency Graphs, etc.
#
# 26. Another way to visualize changing word frequencies over time is through a dispersion plot. One way to create a dispersion plot is to work with a master text that contains all SOTU texts arranged in chronological order. We can access such a "master text" in the "allSotus.txt" file.

# %%
tokenizer = RegexpTokenizer(r'\w+')
#from nltk.tokenize import reg
start = time.time()
with open("allSotus.txt",encoding='utf-8') as f:
    allSotus = f.read()
print(time.time()-start)
print(len(allSotus))
print(sotudf['numtoks'].sum())
#fdist = Counter(nltk.word_tokenize(allSotus))
#tokens = word_tokenize(allSotus) #this takes a long time
alltoks=tokenizer.tokenize(allSotus)
print(len(alltoks))
print(time.time()-start)
txt = nltk.Text(alltoks)
print(time.time()-start)
# Out:
# 0.04142594337463379
# 10604117
# 1786621
# 1786621
# 0.731712818145752
# 0.7495181560516357

# %%
print(len(alltoks))
txt.dispersion_plot(["taxes", "democracy", "freedom", "God", "Indians"])   #the dispersion_plot function is from the nltk library
# Out:
# 1786621

# %% [markdown]
# ## Appendix 1: Creating a Graph of the Lexical Diversity of SOTU texts.

# %% [markdown]
# ### Lexical Diversity

# %% [markdown]
# We can quantify the diversity and complexity of a text's vocabulary by calculating its **lexical diversity**. This is calculated simply by dividing the total number of words found in a text by the number of unique words. A text with high lexical diversity has a high percentage of unique words, whereas a text with low lexical diversity repeats the same words frequently.

# %%
#we will use ltokens2, which you may recall excludes punctuation but not stopwords
print("# of words = ",len(ltokens2))  #here we are using ltokens2, because we want to keep the stopwords as part of our count
print("# of unique words = ",len(set(ltokens2)))
lexdiv=len(ltokens2)/len(set(ltokens2))
print(lexdiv)
# Out:
# # of words =  2918
# # of unique words =  1093
# 2.6697163769441903

# %% [markdown]
# *We will come back to this. For example, after learning how to iterate through a corpus of texts, we will compare the lexical diversity of the SOTU texts to examine how it has changed over time and from president to president.*

# %%
start = time.time()
#sotudf['numUniq'] = len(set(sotudf['tokens']))
sotudf['numUniq'] = sotudf['tokens'].apply(lambda x:len(set(x)))
#sotudf['lexdiv'] = sotudf[ 'numtoks']/sotudf['numUniq']
def doDiv (numer,denom):
    if numer>0:
        ans = numer/denom
    else:
        ans = 0
    return(ans)
sotudf['lexdiv'] = sotudf.apply(lambda x: doDiv(x.numUniq,x.numtoks), axis = 1)
print(time.time() - start)
sotudf.head(20)
# Out:
# 0.077178955078125
#           pres  year  numtoks  \
# 0   Washington  1790        0
# 1   Washington  1791     2314
# 2   Washington  1792     2104
# 3   Washington  1793     1973
# 4   Washington  1794     2918
# 5   Washington  1795     1988
# 6   Washington  1796     2878
# 7        Adams  1797     2060
# 8        Adams  1798     2218
# 9        Adams  1799     1505
# 10       Adams  1800     1374
# 11   Jefferson  1801     3226
# 12   Jefferson  1802     2209
# 13   Jefferson  1803     2283
# 14   Jefferson  1804     2108
# 15   Jefferson  1805     2951
# 16   Jefferson  1806     2872
# 17   Jefferson  1807     2399
# 18   Jefferson  1808     2695
# 19     Madison  1809     1833
#
#                                                tokens  \
# 0                                                  []
# 1   [Fellow, Citizens, of, the, Senate, and, House...
# 2   [Fellow, Citizens, of, the, Senate, and, House...
# 3   [Fellow, Citizens, of, the, Senate, and, House...
# 4   [Fellow, Citizens, of, the, Senate, and, House...
# 5   [Fellow, Citizens, of, the, Senate, and, House...
# 6   [Fellow, Citizens, of, the, Senate, and, House...
# 7   [Gentlemen, of, the, Senate, and, Gentlemen, o...
#